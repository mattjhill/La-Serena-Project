# %% [markdown]
# # Looking for supermassive black hole binaries in CRTS data
# #### Catalina Flores, Matthew Hill, Shiyuan He

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# This project aims at searching strong periodical signal within  247,000 known, spectroscopically confirmed quasars. These are possibly supermassive black hole binaries.
#
# 1. Clean observation by robust statistical method.
# 2. Estimate the period by Lomb-Scarge method and AOV. The results of two methods are convolved together.
# 3. Simulation

# %% [markdown]
# ## 2. Light Curve Cleaning

# %% [markdown]
# Get the outlier removed, but still retain the signal.
# <img src="./figurePart2/clean300.png" style="width: 500px;">

# %% [markdown]
# 1. Fit LOWESS to light curve. This method is robust to outlier.
# 2. Compute the residuals.
# 3. For <strong>ALL</strong> light curves, compute the proportion of removed points, for which absolute value is larger than a threshold.
# 4. Choose threshold value <strong>0.54</strong>, such that <strong>9%</strong> of points are removed.
# <img src="./figurePart2/threshCut.png" style="width: 500px;">
# <br/>
# <br/>
# More Cuts Result
# <img src="./figurePart2/clean301.png" style="width: 500px;">
# <img src="./figurePart2/clean302.png" style="width: 500px;">
# <img src="./figurePart2/clean600.png" style="width: 500px;">
# <img src="./figurePart2/clean601.png" style="width: 500px;">

# %% [markdown]
# We have multiple observation for each MJD. After removing outliers, the observed magnitude is averaged for each unique MJD.
# <img src="./figurePart2/clean300.png" style="width: 400px;"> <img src="./figurePart2/Ave300.png" style="width: 400px;">
# The number of points of each light curve will be significantly reduced. This would facilitate period computation.
# <img src="./figurePart2/ObsCount.png" style="width: 500px;">
# <img src="./figurePart2/uniqueCount.png" style="width: 500px;">

# %% [markdown]
# ## 3. Period Estimation
#
# Code for Fast Lomb-Scargle and AOV publicly available with `gatspy` and `pyaov`!

# %%
data = np.loadtxt("../../file2", usecols=[1,2,3,4])
plt.hist(data[~np.isnan(data[:,3]) & (data[:,3] != 0)][:,3], bins=200, histtype='step')
# Out:
# (array([  1.70000000e+01,   5.50000000e+01,   3.26000000e+02,
#           1.38400000e+03,   5.18900000e+03,   9.90400000e+03,
#           1.39460000e+04,   1.60400000e+04,   1.67410000e+04,
#           1.61850000e+04,   1.51470000e+04,   1.36900000e+04,
#           1.19920000e+04,   1.02280000e+04,   8.22300000e+03,
#           6.60800000e+03,   5.17300000e+03,   4.35400000e+03,
#           3.66400000e+03,   2.93800000e+03,   2.73200000e+03,
#           2.29800000e+03,   2.12900000e+03,   1.93200000e+03,
#           1.80700000e+03,   1.68100000e+03,   1.53700000e+03,
#           1.50900000e+03,   1.31800000e+03,   1.40300000e+03,
#           1.30800000e+03,   1.23500000e+03,   1.16700000e+03,
#           1.14300000e+03,   1.13600000e+03,   1.04000000e+03,
#           1.06100000e+03,   9.82000000e+02,   9.89000000e+02,
#           9.43000000e+02,   9.25000000e+02,   8.88000000e+02,
#           8.55000000e+02,   8.59000000e+02,   7.77000000e+02,
#           7.78000000e+02,   7.67000000e+02,   7.84000000e+02,
#           7.20000000e+02,   7.24000000e+02,   6.85000000e+02,
#           6.51000000e+02,   6.81000000e+02,   6.22000000e+02,
#           6.36000000e+02,   6.29000000e+02,   6.28000000e+02,
#           6.44000000e+02,   5.64000000e+02,   5.63000000e+02,
#           5.68000000e+02,   5.59000000e+02,   5.31000000e+02,
#           4.91000000e+02,   4.76000000e+02,   4.92000000e+02,
#           4.33000000e+02,   4.41000000e+02,   4.12000000e+02,
#           1.47666876e+02,   1.49559595e+02,   1.51452315e+02,
#           1.53345034e+02,   1.55237753e+02,   1.57130472e+02,
#           1.59023191e+02,   1.60915910e+02,   1.62808630e+02,
#           1.64701349e+02,   1.66594068e+02,   1.68486787e+02,
#           1.70379506e+02,   1.72272225e+02,   1.74164944e+02,
#           1.76057664e+02,   1.77950383e+02,   1.79843102e+02,
#           1.81735821e+02,   1.83628540e+02,   1.85521259e+02,
#           1.87413979e+02,   1.89306698e+02,   1.91199417e+02,
#           1.93092136e+02,   1.94984855e+02,   1.96877574e+02,
#           1.98770294e+02,   2.00663013e+02,   2.02555732e+02,
#           2.04448451e+02,   2.06341170e+02,   2.08233889e+02,
#           2.10126609e+02,   2.12019328e+02,   2.13912047e+02,
#           2.15804766e+02,   2.17697485e+02,   2.19590204e+02,
#           2.21482924e+02,   2.23375643e+02,   2.25268362e+02,
#           2.27161081e+02,   2.29053800e+02,   2.30946519e+02,
#           2.32839238e+02,   2.34731958e+02,   2.36624677e+02,
#           2.38517396e+02,   2.40410115e+02,   2.42302834e+02,
#           2.44195553e+02,   2.46088273e+02,   2.47980992e+02,
#           2.49873711e+02,   2.51766430e+02,   2.53659149e+02,
#           2.55551868e+02,   2.57444588e+02,   2.59337307e+02,
#           2.61230026e+02,   2.63122745e+02,   2.65015464e+02,
#           2.66908183e+02,   2.68800903e+02,   2.70693622e+02,
#           2.72586341e+02,   2.74479060e+02,   2.76371779e+02,
#           2.78264498e+02,   2.80157217e+02,   2.82049937e+02,
#           2.83942656e+02,   2.85835375e+02,   2.87728094e+02,
#           2.89620813e+02,   2.91513532e+02,   2.93406252e+02,
#           2.95298971e+02,   2.97191690e+02,   2.99084409e+02,
#           3.00977128e+02,   3.02869847e+02,   3.04762567e+02,
#           3.06655286e+02,   3.08548005e+02,   3.10440724e+02,
#           3.12333443e+02,   3.14226162e+02,   3.16118882e+02,
#           3.18011601e+02,   3.19904320e+02,   3.21797039e+02,
#           3.23689758e+02,   3.25582477e+02,   3.27475196e+02,
#           3.29367916e+02,   3.31260635e+02,   3.33153354e+02,
#           3.35046073e+02,   3.36938792e+02,   3.38831511e+02,
#           3.40724231e+02,   3.42616950e+02,   3.44509669e+02,
#           3.46402388e+02,   3.48295107e+02,   3.50187826e+02,
#           3.52080546e+02,   3.53973265e+02,   3.55865984e+02,
#           3.57758703e+02,   3.59651422e+02,   3.61544141e+02,
#           3.63436861e+02,   3.65329580e+02,   3.67222299e+02,
#           3.69115018e+02,   3.71007737e+02,   3.72900456e+02,
#           3.74793175e+02,   3.76685895e+02,   3.78578614e+02]),
#  <a list of 1 Patch objects>)

# %%
import pyaov

from lightcurve import LightCurve
lc = LightCurve("../../lightcurves/84/1001084016441.dat")
lc.analyze("/dev/null")
lc.plotObs()
# Out:
# Time Series Analysis Package (TSA)
# by Alex Schwarzenberg-Czerny (C)2011
#
# Routines: amhw, aovw, atrw, covar, fgrid, fouw, normalize, peak,
# pldat, plper, prew, pspw, totals
# For help type e.g.: help(pyaov.amhw)
#
# General Reference:
# Schwarzenberg-Czerny, A., 1998, Baltic Astronomy, v.7, p.43-69
#
# 144000 144000
# best period at 3757.297 days, 160.62 sigma from the median

# %%
lc.plot_phase(3757.297)

# %% [markdown]
# ## 4. Simulation
